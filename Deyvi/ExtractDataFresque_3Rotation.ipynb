# %%
import cv2

import matplotlib.pyplot as plt

import numpy as np

import os

from PIL import Image
import random

#import imutils 

from skimage.feature import match_descriptors
from skimage.measure import ransac
from skimage.transform import ProjectiveTransform

# %%
pair_path = 'fresques/Leonardo-da-Vinci_Ultima-Cena_5193x2926/Leonardo-da-Vinci_Ultima-Cena_5193x2926_2019-2-28_13.56.32/frag_eroded'
pair_path_fresque = 'fresques/Leonardo-da-Vinci_Ultima-Cena_5193x2926/Leonardo-da-Vinci_Ultima-Cena_5193x2926.ppm'
pair_path_text = 'fresques/Leonardo-da-Vinci_Ultima-Cena_5193x2926/Leonardo-da-Vinci_Ultima-Cena_5193x2926_2019-2-28_13.56.32/fragments2.txt'


nbr_im1 = 0 #random.randint(0, 295)
nbr_im2 = 25

image1 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{}_color.ppm'.format(nbr_im1))))
# image2 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im2))))
image3 = np.array(Image.open(pair_path_fresque))

def crop_image(img,xC,yC,sizeX,sizeY):
    y,x,z = img.shape
    startx = xC - sizeX//2
    starty = yC - sizeY//2    
    return img[starty:(starty+sizeY),startx:(startx+sizeX),:]


fichier = open(pair_path_text, "r")
text = fichier.read()
data = text.split('\n')
# print(data)

for i in range(len(data)-1):
    id_fragment = int(data[i].split(' ')[0])
    Tx = int(data[i].split(' ')[1])
    Ty = int(data[i].split(' ')[2])
    
    if(nbr_im1 == id_fragment):
        xC1 = int(data[i].split(' ')[1])
        yC1 = int(data[i].split(' ')[2])
        sizeX1 = sizeY1 = int(np.mean(image1.shape[0:2]))
        
#     if(i == int(data[nbr_im2].split(' ')[0])):
#         xC2 = int(data[i].split(' ')[1])
#         yC2 = int(data[i].split(' ')[2])
#         sizeX2 = sizeY2 = int(max(image2.shape)*1.5)
        

im = Image.fromarray(image1)
im.save("qualitative/images_rot/pair_1/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_1/2.jpg")

plt.figure()
plt.imshow(image1)
plt.axis('off')
plt.show()

theta = 90
im_rot_1 = np.rot90(image1)
im = Image.fromarray(im_rot_1)
im.save("qualitative/images_rot/pair_2/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_2/2.jpg")

plt.figure()
plt.imshow(im_rot_1)
plt.axis('off')
plt.show()

theta = 90
im_rot_2 = np.rot90(im_rot_1)
im = Image.fromarray(im_rot_2)
im.save("qualitative/images_rot/pair_3/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_3/2.jpg")

plt.figure()
plt.imshow(im_rot_2)
plt.axis('off')
plt.show()

theta = 90
im_rot_3 = np.rot90(im_rot_2)
im = Image.fromarray(im_rot_3)
im.save("qualitative/images_rot/pair_4/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_4/2.jpg")

plt.figure()
plt.imshow(im_rot_3)
plt.axis('off')
plt.show()


plt.figure()
plt.imshow(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
plt.axis('off')
plt.show()

# %%
pair_path = 'fresques/Leonardo-da-Vinci_Ultima-Cena_5193x2926/Leonardo-da-Vinci_Ultima-Cena_5193x2926_2019-2-28_13.56.32/frag_eroded'
pair_path_fresque = 'fresques/Leonardo-da-Vinci_Ultima-Cena_5193x2926/Leonardo-da-Vinci_Ultima-Cena_5193x2926.ppm'
pair_path_text = 'fresques/Leonardo-da-Vinci_Ultima-Cena_5193x2926/Leonardo-da-Vinci_Ultima-Cena_5193x2926_2019-2-28_13.56.32/fragments2.txt'


nbr_im1 = 22 #random.randint(0, 295)
nbr_im2 = 25

image1 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{}_color.ppm'.format(nbr_im1))))
# image2 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im2))))
image3 = np.array(Image.open(pair_path_fresque))

def crop_image(img,xC,yC,sizeX,sizeY):
    y,x,z = img.shape
    startx = xC - sizeX//2
    starty = yC - sizeY//2    
    return img[starty:(starty+sizeY),startx:(startx+sizeX),:]


fichier = open(pair_path_text, "r")
text = fichier.read()
data = text.split('\n')
# print(data)

for i in range(len(data)-1):
    id_fragment = int(data[i].split(' ')[0])
    Tx = int(data[i].split(' ')[1])
    Ty = int(data[i].split(' ')[2])
    
    
    
    if(nbr_im1 == id_fragment):
        xC1 = int(data[i].split(' ')[1])
        yC1 = int(data[i].split(' ')[2])
        sizeX1 = sizeY1 = int(np.mean(image1.shape[0:2]))
    print(Tx,Ty,sizeX1)
        
#     if(i == int(data[nbr_im2].split(' ')[0])):
#         xC2 = int(data[i].split(' ')[1])
#         yC2 = int(data[i].split(' ')[2])
#         sizeX2 = sizeY2 = int(max(image2.shape)*1.5)
        

im = Image.fromarray(image1)
im.save("qualitative/images_rot/pair_5/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_5/2.jpg")

plt.figure()
plt.imshow(image1)
plt.axis('off')
plt.show()

theta = 90
im_rot_1 = np.rot90(image1)
im = Image.fromarray(im_rot_1)
im.save("qualitative/images_rot/pair_6/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_6/2.jpg")

plt.figure()
plt.imshow(im_rot_1)
plt.axis('off')
plt.show()

theta = 90
im_rot_2 = np.rot90(im_rot_1)
im = Image.fromarray(im_rot_2)
im.save("qualitative/images_rot/pair_7/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_7/2.jpg")

plt.figure()
plt.imshow(im_rot_2)
plt.axis('off')
plt.show()

theta = 90
im_rot_3 = np.rot90(im_rot_2)
im = Image.fromarray(im_rot_3)
im.save("qualitative/images_rot/pair_8/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_8/2.jpg")

plt.figure()
plt.imshow(im_rot_3)
plt.axis('off')
plt.show()


plt.figure()
plt.imshow(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
plt.axis('off')
plt.show()
# Out:
# 282 2223 353

# %%
print(2223-353//2)
# Out:
# 2047

# %%
pair_path = os.path.join('6fresques_et','Leonardo-da-Vinci_Ultima-Cena_5193x2926','frag_eroded')
pair_path_fresque = os.path.join('6fresques_et','Leonardo-da-Vinci_Ultima-Cena_5193x2926','Leonardo-da-Vinci_Ultima-Cena_5193x2926.ppm')
pair_path_text = '6fresques_et/Leonardo-da-Vinci_Ultima-Cena_5193x2926/fragments.txt'

nbr_im1 = 25 #random.randint(0, 295)

image1 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im1))))
image2 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im2))))
image3 = np.array(Image.open(pair_path_fresque))

def crop_image(img,xC,yC,sizeX,sizeY):
    y,x,z = img.shape
    startx = xC - sizeX//2
    starty = yC - sizeY//2    
    return img[starty:(starty+sizeY),startx:(startx+sizeX),:]


fichier = open(pair_path_text, "r")
text = fichier.read()
data = text.split('\n')

for i in range(len(data)):
    if(i == int(data[nbr_im1].split(' ')[0])):
        xC1 = int(data[i].split(' ')[1])
        yC1 = int(data[i].split(' ')[2])
        sizeX1 = sizeY1 = int(max(image1.shape)*1.5)
        
    if(i == int(data[nbr_im2].split(' ')[0])):
        xC2 = int(data[i].split(' ')[1])
        yC2 = int(data[i].split(' ')[2])
        sizeX2 = sizeY2 = int(max(image2.shape)*1.5)
        

im = Image.fromarray(image1)
im.save("qualitative/images_rot/pair_5/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_5/2.jpg")

plt.figure()
plt.imshow(image1)
plt.axis('off')
plt.show()

theta = 90
im_rot_1 = np.rot90(image1)
im = Image.fromarray(im_rot_1)
im.save("qualitative/images_rot/pair_6/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_6/2.jpg")

plt.figure()
plt.imshow(im_rot_1)
plt.axis('off')
plt.show()

theta = 90
im_rot_2 = np.rot90(im_rot_1)
im = Image.fromarray(im_rot_2)
im.save("qualitative/images_rot/pair_7/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_7/2.jpg")

plt.figure()
plt.imshow(im_rot_2)
plt.axis('off')
plt.show()

theta = 90
im_rot_3 = np.rot90(im_rot_2)
im = Image.fromarray(im_rot_3)
im.save("qualitative/images_rot/pair_8/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_8/2.jpg")

plt.figure()
plt.imshow(im_rot_3)
plt.axis('off')
plt.show()


plt.figure()
plt.imshow(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
plt.axis('off')
plt.show()

# %%
pair_path = os.path.join('6fresques_et','Michelangelo_ThecreationofAdam_1707x775','frag_eroded')
pair_path_fresque = os.path.join('6fresques_et','Michelangelo_ThecreationofAdam_1707x775','Michelangelo_ThecreationofAdam_1707x775.ppm')
pair_path_text = '6fresques_et/Michelangelo_ThecreationofAdam_1707x775/fragments.txt'

nbr_im1 = 4 #28 #random.randint(0, 295)

image1 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im1))))
image2 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im2))))
image3 = np.array(Image.open(pair_path_fresque))

def crop_image(img,xC,yC,sizeX,sizeY):
    y,x,z = img.shape
    startx = xC - sizeX//2
    starty = yC - sizeY//2    
    return img[starty:(starty+sizeY),startx:(startx+sizeX),:]


fichier = open(pair_path_text, "r")
text = fichier.read()
data = text.split('\n')

for i in range(len(data)):
    if(i == int(data[nbr_im1].split(' ')[0])):
        xC1 = int(data[i].split(' ')[1])
        yC1 = int(data[i].split(' ')[2])
        sizeX1 = sizeY1 = int(max(image1.shape)*1.5)
        
    if(i == int(data[nbr_im2].split(' ')[0])):
        xC2 = int(data[i].split(' ')[1])
        yC2 = int(data[i].split(' ')[2])
        sizeX2 = sizeY2 = int(max(image2.shape)*1.5)
        

im = Image.fromarray(image1)
im.save("qualitative/images_rot/pair_13/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_13/2.jpg")

plt.figure()
plt.imshow(image1)
plt.axis('off')
plt.show()

theta = 90
im_rot_1 = np.rot90(image1)
im = Image.fromarray(im_rot_1)
im.save("qualitative/images_rot/pair_14/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_14/2.jpg")

plt.figure()
plt.imshow(im_rot_1)
plt.axis('off')
plt.show()

theta = 90
im_rot_2 = np.rot90(im_rot_1)
im = Image.fromarray(im_rot_2)
im.save("qualitative/images_rot/pair_15/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_15/2.jpg")

plt.figure()
plt.imshow(im_rot_2)
plt.axis('off')
plt.show()

theta = 90
im_rot_3 = np.rot90(im_rot_2)
im = Image.fromarray(im_rot_3)
im.save("qualitative/images_rot/pair_16/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_16/2.jpg")

plt.figure()
plt.imshow(im_rot_3)
plt.axis('off')
plt.show()


plt.figure()
plt.imshow(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
plt.axis('off')
plt.show()

# %%
pair_path = os.path.join('6fresques_et','Perugino_Consegnadellechiavi_2347x1438','frag_eroded')
pair_path_fresque = os.path.join('6fresques_et','Perugino_Consegnadellechiavi_2347x1438','Perugino_Consegnadellechiavi_2347x1438.ppm')
pair_path_text = '6fresques_et/Perugino_Consegnadellechiavi_2347x1438/fragments.txt'

nbr_im1 = 0 #random.randint(0, 295)
nbr_im2 = 1 #random.randint(0, 295)

image1 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im1))))
image2 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im2))))
image3 = np.array(Image.open(pair_path_fresque))

def crop_image(img,xC,yC,sizeX,sizeY):
    y,x,z = img.shape
    startx = xC - sizeX//2
    starty = yC - sizeY//2    
    return img[starty:(starty+sizeY),startx:(startx+sizeX),:]


fichier = open(pair_path_text, "r")
text = fichier.read()
data = text.split('\n')



xC1 = int(data[nbr_im1].split(' ')[1])
yC1 = int(data[nbr_im1].split(' ')[2])
sizeX1 = sizeY1 = int(max(image1.shape)*1.5)

xC2 = int(data[nbr_im2].split(' ')[1])
yC2 = int(data[nbr_im2].split(' ')[2])
sizeX2 = sizeY2 = int(max(image2.shape)*1.5)
        

im = Image.fromarray(image1)
im.save("qualitative/images_rot/pair_17/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_17/2.jpg")

plt.figure()
plt.imshow(image1)
plt.axis('off')
plt.show()

theta = 90
im_rot_1 = np.rot90(image1)
im = Image.fromarray(im_rot_1)
im.save("qualitative/images_rot/pair_18/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_18/2.jpg")

plt.figure()
plt.imshow(im_rot_1)
plt.axis('off')
plt.show()

theta = 90
im_rot_2 = np.rot90(im_rot_1)
im = Image.fromarray(im_rot_2)
im.save("qualitative/images_rot/pair_19/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_19/2.jpg")

plt.figure()
plt.imshow(im_rot_2)
plt.axis('off')
plt.show()

theta = 90
im_rot_3 = np.rot90(im_rot_2)
im = Image.fromarray(im_rot_3)
im.save("qualitative/images_rot/pair_20/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images_rot/pair_20/2.jpg")

plt.figure()
plt.imshow(im_rot_3)
plt.axis('off')
plt.show()


plt.figure()
plt.imshow(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
plt.axis('off')
plt.show()

# %%
pair_path = os.path.join('6fresques_et','Piero-della-Francesca_ExaltationoftheCross_1239x900','frag_eroded')
pair_path_fresque = os.path.join('6fresques_et','Piero-della-Francesca_ExaltationoftheCross_1239x900','Piero-della-Francesca_ExaltationoftheCross_1239x900.ppm')
pair_path_text = '6fresques_et/Piero-della-Francesca_ExaltationoftheCross_1239x900/fragments.txt'

nbr_im1 = 126 #random.randint(0, 295)
nbr_im2 = 125

image1 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im1))))
image2 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im2))))
image3 = np.array(Image.open(pair_path_fresque))

def crop_image(img,xC,yC,sizeX,sizeY):
    y,x,z = img.shape
    startx = xC - sizeX//2
    starty = yC - sizeY//2    
    return img[starty:(starty+sizeY),startx:(startx+sizeX),:]


fichier = open(pair_path_text, "r")
text = fichier.read()
data = text.split('\n')

print(len(data))

for i in range(len(data)):
    t = data[i].split(' ')[0]
    if(nbr_im1 == t):
        xC1 = int(data[i].split(' ')[1])
        yC1 = int(data[i].split(' ')[2])
        sizeX1 = sizeY1 = int(max(image1.shape)*1.5)
        print(i)
        
    if(nbr_im2 == t):
        xC2 = int(data[i].split(' ')[1])
        yC2 = int(data[i].split(' ')[2])
        sizeX2 = sizeY2 = int(max(image2.shape)*1.5)
        print(i)

im = Image.fromarray(image1)
im.save("qualitative/images/pair_12/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images/pair_12/2.jpg")

im = Image.fromarray(image2)
im.save("qualitative/images/pair_13/1.jpg")

im = Image.fromarray(crop_image(image3,xC2,yC2,sizeX2,sizeY2))
im.save("qualitative/images/pair_13/2.jpg")

plt.figure()
plt.imshow(image1)
plt.axis('off')
plt.show()

plt.figure()
plt.imshow(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
plt.axis('off')
plt.show()

plt.figure()
plt.imshow(image2)
plt.axis('off')
plt.show()

plt.figure()
plt.imshow(crop_image(image3,xC2,yC2,sizeX2,sizeY2))
plt.axis('off')
plt.show()
# Out:
# 301

# %%
pair_path = os.path.join('6fresques_et','Tiepolo_TheInstitutionoftheRosary_850x1231','frag_eroded')
pair_path_fresque = os.path.join('6fresques_et','Tiepolo_TheInstitutionoftheRosary_850x1231','Tiepolo_TheInstitutionoftheRosary_850x1231.ppm')
pair_path_text = '6fresques_et/Tiepolo_TheInstitutionoftheRosary_850x1231/fragments.txt'

nbr_im1 = 17
nbr_im2 = 22

print(nbr_im1)
print(nbr_im2)

image1 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im1))))
image2 = np.array(Image.open(os.path.join(pair_path, 'frag_eroded_{:04d}.ppm'.format(nbr_im2))))
image3 = np.array(Image.open(pair_path_fresque))

def crop_image(img,xC,yC,sizeX,sizeY):
    y,x,z = img.shape
    startx = xC - sizeX//2
    starty = yC - sizeY//2    
    return img[starty:(starty+sizeY),startx:(startx+sizeX),:]


fichier = open(pair_path_text, "r")
text = fichier.read()
data = text.split('\n')

for i in range(len(data)):
    t = data[i].split(' ')[0]
    if(nbr_im1 == t):
        xC1 = int(data[i].split(' ')[1])
        yC1 = int(data[i].split(' ')[2])
        sizeX1 = sizeY1 = int(max(image1.shape)*1.5)
        print(i)
        
    if(nbr_im2 == t):
        xC2 = int(data[i].split(' ')[1])
        yC2 = int(data[i].split(' ')[2])
        sizeX2 = sizeY2 = int(max(image2.shape)*1.5)
        print(i)

im = Image.fromarray(image1)
im.save("qualitative/images/pair_14/1.jpg")

im = Image.fromarray(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
im.save("qualitative/images/pair_14/2.jpg")

im = Image.fromarray(image2)
im.save("qualitative/images/pair_15/1.jpg")

im = Image.fromarray(crop_image(image3,xC2,yC2,sizeX2,sizeY2))
im.save("qualitative/images/pair_15/2.jpg")

plt.figure()
plt.imshow(image1)
plt.axis('off')
plt.show()

plt.figure()
plt.imshow(crop_image(image3,xC1,yC1,sizeX1,sizeY1))
plt.axis('off')
plt.show()

plt.figure()
plt.imshow(image2)
plt.axis('off')
plt.show()

plt.figure()
plt.imshow(crop_image(image3,xC2,yC2,sizeX2,sizeY2))
plt.axis('off')
plt.show()
# Out:
# 17
# 22

# %%
pair_idx = 4
pair_path = os.path.join('images', 'pair_%d' % pair_idx)
image1 = np.array(Image.open(os.path.join(pair_path, 'fresqueComplete.ppm')))
image2 = np.array(Image.open(os.path.join(pair_path, '1.ppm')))
plt.figure()
plt.imshow(image2)
plt.axis('off')
plt.show()

def crop_image(img,xC,yC,sizeX,sizeY):
    y,x,z = img.shape
    startx = xC - sizeX//2
    starty = yC - sizeY//2    
    return img[starty:(starty+sizeY),startx:(startx+sizeX),:]

xC = 1526
yC = 411
sizeX = sizeY = 200

image3 = crop_image(image1,xC,yC,sizeX,sizeY)
plt.figure()
plt.imshow(image3)
plt.axis('off')
plt.show()

im = Image.fromarray(image2)
im.save("images/pair_4/1.jpg")

im = Image.fromarray(image3)
im.save("images/pair_4/2.jpg")

print(image3.shape)
